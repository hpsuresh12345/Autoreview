# %% [markdown]
# <a href="https://colab.research.google.com/github/hpsuresh12345/Autoreview/blob/master/Tweepy_Keywords_AutomotiveInfotainment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tweepy as tw
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections
from textblob import TextBlob
import matplotlib

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

% matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
consumer_key='IMSGuvTMAxaUDaUGnFrsY45xb'
consumer_secret='Xhxgez2I6CNildApP1f0uWkb0GOHZEXMpXriQqQ7aon3V8oZGO'
access_token='238097127-nqF8l4kJPg4VA4C2ANrp0rbmZKlyW3YqQa5Q4Nk0'
access_token_secret='FOBOIMJ3Fv6TKZPdsqCT2y4DYiTQDqpEmrQs0ukl1NDwg'

# %%
auth=tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api=tw.API(auth,wait_on_rate_limit=True)

# %%
tweets=tw.Cursor(api.search, q='@jblaudio-filter:retweets',lang='en',since='2018-01-01').items(10000)

# %%
tweets_text=[tweet.text for tweet in tweets]
tweets_text
# Out:
# ["Banging out @Slipmatt @WorldOfRave #302 on my new #JBL speaker. Loving the '92 sound, hard, fast and dark. @JBLaudio https://t.co/0qG1Hb1jb0",
#  "Hey guys I have my speaker for a part change 4 months and it's only being delayed from your side now.\nDisappointed… https://t.co/KbgxwwnYMf",
#  "@JBLaudio @JBLSoundIn They might be able to but they won't or  they're trying very hard not to. It's been 3 months… https://t.co/x9n7LBKpUt",
#  'Oh no! I recently noticed that one of my Playlists stopped working. I hope @JBLaudio takes care of me. https://t.co/Gc9JdNs1XV',
#  "@JBLaudio hey, The set is damaged, and the wire is sticky. Bought it from @amazonIN in April, hopefully it's still… https://t.co/vOeCkHB69l",
#  '@evaride @JBLaudio Dude your show there was absolutely amazing!! A new fan was born',
#  "O artık bir Gold Edition!😎\nIt's a Gold Edition now! \nDear @JBLaudio, do you need any employee in your design depart… https://t.co/QoZ2vajyJd",
# ...

# %%
tweets1=tw.Cursor(api.search,q='#infotainment-filter:retweets',lang="en",since='2018-01-01').items(10000)
tweets_text1=[tweet.text for tweet in tweets1]
tweets_text1
# Out:
# ["Lourds Lane nails it at BlogHer '13: https://t.co/DpwCZ5PfLh  #Keynote #Speakers #Women #Retreats #Summits… https://t.co/WDyHXIV02g",
#  "UN Youth Ambassador and #antibullying icon, Meredith O'Connor, rocked it at the UN CSW Youth Forum! To book Meredit… https://t.co/wC8DqUX9iV",
#  'Want amazing #speakers to rock your event? Featured: Ernie Hudson, George Takei, Jay Mohr &amp; Lefty Williams, former… https://t.co/G4siPmwyNF',
#  'If people stopped watching #infotainment and #entertainment and started watching #publicAffairs they might see what… https://t.co/s07l7aRa1v',
#  'Yvette Nicole Brown is not only an absolutely amazing speaker, but she delivers a message that audiences will never… https://t.co/IOSqWE2zx3',
#  'Prince Ea\'s "I QUIT" is one of his best messages yet! Watch here: https://t.co/Q1dd9sLliT  To book Prince Ea, DM .… https://t.co/dCpnfIYNIf',
# ...

# %%
tweets2=tw.Cursor(api.search,q='#AndroidAuto-filter:retweets',lang="en",since='2018-01-01').items(10000)
tweets_text2=[tweet.text for tweet in tweets2]
tweets_text2
# Out:
# ['@Android Help ! 🙏🏻 #AndroidAuto',
#  '@Android #androidauto With a Huawei P20 Pro, since a couple of weeks, when I receive a notification (mail or WhatsA… https://t.co/W6unCTFWOX',
#  'Check out my review of my new Kia Rio, and the frustrations of getting my Android Auto set up.  Thought I was tech… https://t.co/vx7OIR1qh3',
#  '@android please help #androidauto with problem not receiving text messages on AA.  I have a 2019 Jeep Cherokee Ltd… https://t.co/yj59SuNq2x',
#  '@android Please help #androidauto with problem not receiving text messages on the AA.  I have a 2019 Jeep Cherokee… https://t.co/ODv3oPHDRe',
#  'Nissan Titan came in for a new #DMX706s #carplay and #androidauto media player from @KENWOODUSA and back up camera… https://t.co/6GPNlEkFPz',
#  '@Android #androidauto \nHi, \nWhen will Android Auto be officially available in Israel?',
# ...

# %%
tweets3=tw.Cursor(api.search,q='#carplay-filter:retweets',lang="en",since='2018-01-01').items(10000)
tweets_text3=[tweet.text for tweet in tweets3]
tweets_text3
# Out:
# ['After continuously getting «Could not establish @Apple #CarPlay connection» in my car, I find that «Siri must be en… https://t.co/fiNhA6RhP6',
#  'Who can I thank for the new #Apple #CarPlay upgrade with #iOS13?! Love it! You all hit some major pain points. 👏 👏  thank you 🙏 @Apple',
#  '@seanryyyan @Apple I am going to write to @apple #carplay is having issues with many cars',
#  "@BMW's now charging $300 for owners to use @Apple #CarPlay since their infotainment sucks &amp; #Apple gets $0 from… https://t.co/kasmqxSQia",
#  "@BMW's extra \u2066@Apple\u2069 #CarPlay fee on luxury SUV is a money grab. Next will be a convenience fee to start car.  https://t.co/xoMYXLICFu",
#  '#CarPlay’s new dashboard. #Appls #iOS13. https://t.co/CrC8niifWS',
#  'You know what would be really handy? #paystay on #apple #carplay',
#  'CarPlay for #iOS13 review on a big screen: The difference is incredible #carplay #Apple https://t.co/BqETZSOwz6 https://t.co/M3495dzR9E',
# ...
